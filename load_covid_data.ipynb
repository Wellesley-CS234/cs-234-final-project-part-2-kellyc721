# %%
import pandas as pd

# %%
df = pd.read_csv("/Users/Kelly/Documents/Documents/CS 234/cs-234-fp-class-demo-kellyc721/covid_articles_matched_qids.csv", encoding="utf-8", parse_dates=["date"])

# %%
df.head()
# Out:
#         date country_code       project                       article  \
# 0 2023-02-07           FR  fr.wikipedia    Maladie à coronavirus 2019
# 1 2023-02-07           IN  mr.wikipedia                 कोरोनाव्हायरस
# 2 2023-02-07           TW  zh.wikipedia                 2019冠狀病毒病臺灣疫情
# 3 2023-02-07           IN  en.wikipedia  2019–20 coronavirus pandemic
# 4 2023-02-07           US  en.wikipedia     World Health Organization
#
#          qid  pageviews
# 0  Q84263196         92
# 1  Q57751738         90
# 2  Q84081307        272
# 3  Q81068910        714
# 4      Q7817       1278

# %%
df.to_csv("data/covid_articles_matched_qids.csv", index=False)
